# %% [markdown]
# <a href="https://colab.research.google.com/github/alecrisan313/bookshelf_inspector_client/blob/main/Bookshelf_Inspector_client_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unzip the data from Book-Crossing Dataset and make the dataframes

# %%
# !unzip BX-CSV-Dump.zip
# Out:
# Archive:  BX-CSV-Dump.zip
#   inflating: BX-Book-Ratings.csv
#   inflating: BX-Books.csv
#   inflating: BX-Users.csv

# %%
import pandas as pd

book_ratings_df = pd.read_csv("BX-Book-Ratings.csv", sep=";", encoding= 'unicode_escape')
books_df = pd.read_csv("BX-Books.csv", sep=";", encoding= 'unicode_escape', on_bad_lines='skip')
users_df = pd.read_csv("BX-Users.csv", sep=";", encoding= 'unicode_escape')
# Out:
# <ipython-input-126-f6e13a83fa3e>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv("BX-Books.csv", sep=";", encoding= 'unicode_escape', on_bad_lines='skip')

# %%
book_ratings_df
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books_df
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
users_df
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %% [markdown]
# # Clean the data

# %% [markdown]
# Drop duplicates if they exist so they only appear once:

# %%
book_ratings_df.drop_duplicates(inplace=True)
books_df.drop_duplicates(inplace=True)
users_df.drop_duplicates(inplace=True)

# %% [markdown]
# Drop N/A rows from the most important columns:
#
# From book_ratings_df: User-ID, ISBN
#
# From books_df: ISBN,	Book-Title,	Book-Author
#
# From users_df: User-ID

# %%
book_ratings_df = book_ratings_df[book_ratings_df['User-ID'].notna()]
book_ratings_df = book_ratings_df[book_ratings_df['ISBN'].notna()]

books_df = books_df[books_df['Book-Title'].notna()]
books_df = books_df[books_df['ISBN'].notna()]
books_df = books_df[books_df['Book-Author'].notna()]

users_df = users_df[users_df['User-ID'].notna()]

# %%
import re

def clean_text_alphanumeric(text):
    pattern = re.compile('[^a-zA-Z0-9]+')
    return pattern.sub('', text)

def clean_text_alphanumeric_punctuation(text):
    pattern = re.compile('[^a-zA-Z0-9]+ .,:!?/')
    return pattern.sub('', text)

# Apply the function to the dataframe column I want to clean
book_ratings_df['ISBN'] = book_ratings_df['ISBN'].apply(lambda x: clean_text_alphanumeric(x))
books_df['ISBN'] = books_df['ISBN'].apply(lambda x: clean_text_alphanumeric(x))
books_df['Book-Title'] = books_df['Book-Title'].apply(lambda x: clean_text_alphanumeric_punctuation(x))

# %% [markdown]
# # The most popular books with explicit rating

# %% [markdown]
# What makes a book popular? The best way I can answer this is by saying that a book is popular if people enjoy reading it.

# %% [markdown]
# Mai intai cele mai populare per general si apoi pe categorii pe varsta: sub 18, 18-25, 25-40, 40+ si locatie

# %% [markdown]
# First, we get the average of the ratings per book

# %%
average_ratings_per_book = book_ratings_df.groupby(['ISBN'], as_index=False)['Book-Rating'].mean()

# %% [markdown]
# We want to keep only the most popular books so they should have a average rating above 7.5

# %%
book_ratings_above_7_df = average_ratings_per_book.drop(average_ratings_per_book[average_ratings_per_book['Book-Rating'] < 7.5].index)

# %% [markdown]
# We sort the ratings in descending order so we can see the most popular books

# %%
book_ratings_above_7_df.sort_values(['Book-Rating'], ascending=False, inplace=True)
book_ratings_above_7_df
# Out:
#                  ISBN  Book-Rating
# 6       0000000000090         10.0
# 210065     0812929950         10.0
# 210170     0812967097         10.0
# 210158     0812966872         10.0
# 210157     0812966864         10.0
# ...               ...          ...
# 164168     0679425411          7.5
# 284762     225314505X          7.5
# 164240     0679429069          7.5
# 92817      0425054578          7.5
# 13230      0062516795          7.5
#
# [52004 rows x 2 columns]

# %% [markdown]
# In order to get the information about the popular books we found we need to join it with the datagrame that contains informations about all the books

# %%
popular_books = pd.merge(book_ratings_above_7_df, books_df, on='ISBN')
popular_books.head(10)
# Out:
#          ISBN  Book-Rating                                         Book-Title  \
# 0  0812929950         10.0       100 Best TV Commercials: And Why They Worked
# 1  0812967097         10.0                               Loose Lips : A Novel
# 2  0812966872         10.0                   It Takes a Worried Man: A Memoir
# 3  0812966864         10.0   Love by the Glass: Tasting Notes from a Marriage
# 4  0812966538         10.0  A Higher Form of Killing: The Secret History o...
# 5  081296389X         10.0  The New York Times Manual of Style and Usage :...
# 6  0812963857         10.0  365 Ways to Get Out the Fat: A Tip a Day to Tr...
# 7  0812963067         10.0                To be a woman in America, 1850-1930
# 8  0812934539         10.0            Stanley Newman's Coffee Time Word Games
# 9  0812933397         10.0  Booknotes Life Stories: Notable Biographers on...
#
#                   Book-Author Year-Of-Publication  \
# 0              Bernice Kanner                1999
# ...

# %% [markdown]
# # The most popular books by age categories

# %% [markdown]
# It is very important the age you have when you read a book so the most popular books can differ from an age category to another.

# %% [markdown]
# sub 18, 18-25, 25-40, 40

# %% [markdown]
# First I get rid of users with N/A age:

# %%
users_with_age_df = users_df[users_df['Age'].notna()]

# %% [markdown]
# The first age category is under 18

# %% [markdown]
# I extract the users that have the age < 18:

# %%
users_under_18 = users_with_age_df.drop(users_with_age_df[users_with_age_df['Age'] >= 18].index)

# %% [markdown]
# I take all the book ratings that are written by users under 18:

# %%
book_ratings_users_under_18 = book_ratings_df[book_ratings_df['User-ID'].isin(users_under_18['User-ID'])]

# %% [markdown]
# I repeat the steps from the most popular books with explicit ratings:

# %%
average_ratings_per_book = book_ratings_users_under_18.groupby(['ISBN'], as_index=False)['Book-Rating'].mean()
book_ratings_above_7_df = average_ratings_per_book.drop(average_ratings_per_book[average_ratings_per_book['Book-Rating'] < 7.5].index)
book_ratings_above_7_df.sort_values(['Book-Rating'], ascending=False, inplace=True)
popular_books_users_under_18 = pd.merge(book_ratings_above_7_df, books_df, on='ISBN')
popular_books_users_under_18
# Out:
#             ISBN  Book-Rating  \
# 0     074341005X         10.0
# 1     0743237188         10.0
# 2     0743244281         10.0
# 3     0743251148         10.0
# 4     074340050X         10.0
# ...          ...          ...
# 3800  1562475150          7.5
# 3801  0394900200          7.5
# 3802  0515087122          7.5
# 3803  0151008116          7.5
# 3804  0425169693          7.5
#
#                                              Book-Title           Book-Author  \
# 0     Give Me My Father's Body : The Life of Minik, ...           Kenn Harper
# 1                        Fall On Your Knees (Oprah #45)   Ann-Marie MacDonald
# 2             Barry Trotter and the Unauthorized Parody        Michael Gerber
# 3     Found : The Best Lost, Tossed, and Forgotten I...         Davy Rothbart
# 4     Avatar Book One of Two (Star Trek Deep Space N...           S. D. Perry
# ...                                                 ...                   ...
# ...

# %% [markdown]
# The second age category is 18 - 25

# %%
users_over_18 = users_with_age_df.drop(users_with_age_df[users_with_age_df['Age'] < 18].index)
users_18_25 = users_over_18.drop(users_over_18[users_over_18['Age'] > 25].index)

# %%
book_ratings_users_18_25 = book_ratings_df[book_ratings_df['User-ID'].isin(users_18_25['User-ID'])]

# %%
average_ratings_per_book = book_ratings_users_18_25.groupby(['ISBN'], as_index=False)['Book-Rating'].mean()
book_ratings_above_7_df = average_ratings_per_book.drop(average_ratings_per_book[average_ratings_per_book['Book-Rating'] < 7.5].index)
book_ratings_above_7_df.sort_values(['Book-Rating'], ascending=False, inplace=True)
popular_books_users_18_25 = pd.merge(book_ratings_above_7_df, books_df, on='ISBN')
popular_books_users_18_25
# Out:
#             ISBN  Book-Rating  \
# 0     1853261203         10.0
# 1     0802134475         10.0
# 2     2706102918         10.0
# 3     8433920472         10.0
# 4     0435126105         10.0
# ...          ...          ...
# 9133  0307248038          7.5
# 9134  1566192951          7.5
# 9135  059042193X          7.5
# 9136  0440941407          7.5
# 9137  089281764X          7.5
#
#                                              Book-Title          Book-Author  \
# 0                     Peter Pan (Wordsworth Collection)         J. M. Barrie
# 1                                                  Rain          Kirsty Gunn
# 2     Petit traitÃ© de manipulation Ã  l'usage des h...         Robert Joule
# 3                                       Sonetos de Amor  William Shakespeare
# 4     New Windmill Classics: Sherlock Holmes Short S...   Arthur Conan Doyle
# ...                                                 ...                  ...
# ...

# %% [markdown]
# The third age category is 26 - 40

# %%
users_over_26 = users_with_age_df.drop(users_with_age_df[users_with_age_df['Age'] < 26].index)
users_26_40 = users_over_18.drop(users_over_18[users_over_18['Age'] > 40].index)

# %%
book_ratings_users_26_40 = book_ratings_df[book_ratings_df['User-ID'].isin(users_26_40['User-ID'])]

# %%
average_ratings_per_book = book_ratings_users_26_40.groupby(['ISBN'], as_index=False)['Book-Rating'].mean()
book_ratings_above_7_df = average_ratings_per_book.drop(average_ratings_per_book[average_ratings_per_book['Book-Rating'] < 7.5].index)
book_ratings_above_7_df.sort_values(['Book-Rating'], ascending=False, inplace=True)
popular_books_users_26_40 = pd.merge(book_ratings_above_7_df, books_df, on='ISBN')
popular_books_users_26_40.head(3)
# Out:
#          ISBN  Book-Rating                                         Book-Title  \
# 0  0883680661         10.0                       What You Say Is What You Get
# 1  0876591195         10.0  Story Stretchers: Activities to Expand Childre...
# 2  0877013802         10.0  Sherlock Holmes' London: Following the Footste...
#
#          Book-Author Year-Of-Publication            Publisher  \
# 0        Don Gossett                1976       Whitaker House
# 1  Shirley C. Raines                1989        Gryphon House
# 2  Tsukasa Kobayashi                1989  Chronicle Books Llc
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0883680661.0...
# 1  http://images.amazon.com/images/P/0876591195.0...
# 2  http://images.amazon.com/images/P/0877013802.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0883680661.0...
# 1  http://images.amazon.com/images/P/0876591195.0...
# ...

# %% [markdown]
# The forth age category is over 40

# %%
users_over_40 = users_with_age_df.drop(users_with_age_df[users_with_age_df['Age'] < 40].index)

# %%
book_ratings_users_over_40 = book_ratings_df[book_ratings_df['User-ID'].isin(users_over_40['User-ID'])]

# %%
average_ratings_per_book = book_ratings_users_over_40.groupby(['ISBN'], as_index=False)['Book-Rating'].mean()
book_ratings_above_7_df = average_ratings_per_book.drop(average_ratings_per_book[average_ratings_per_book['Book-Rating'] < 7.5].index)
book_ratings_above_7_df.sort_values(['Book-Rating'], ascending=False, inplace=True)
popular_books_users_over_40 = pd.merge(book_ratings_above_7_df, books_df, on='ISBN')
popular_books_users_over_40.head(10)
# Out:
#          ISBN  Book-Rating                                         Book-Title  \
# 0  0762407905         10.0                            Little Book of Hanukkah
# 1  1567997708         10.0                                        Lighthouses
# 2  0399508627         10.0           Early Childhood Years : the Two to Six Y
# 3  0762413069         10.0                              Free to Be You and Me
# 4  0399512519         10.0  Catholics: An Unauthorized, Unapproved, Illust...
# 5  0399513442         10.0  Bridal Showers: 50 Great Ideas for a Perfect S...
# 6  0762412208         10.0  Truth/Dare: A Flip Flop Journal (Flip-Flap Jou...
# 7  0762409363         10.0  Bad girls in the big city MAGNETIC POSTCARDS(t...
# 8  156833110X         10.0  Breakin' into Nashville: How to Write and Sell...
# 9  0399516263         10.0                              The Art of Cartooning
#
#              Book-Author Year-Of-Publication                      Publisher  \
# ...

# %% [markdown]
# # The most popular authors

# %% [markdown]
# The most popular authors are those that wrote the most popular books

# %%
popular_authors = popular_books['Book-Author'].to_frame()
popular_authors
# Out:
#              Book-Author
# 0         Bernice Kanner
# 1       CLAIRE BERLINSKI
# 2         Brendan Halpin
# 3      Dorothy J. Gaiter
# 4          Robert Harris
# ...                  ...
# 39180     Michael Shaara
# 39181        Ken Follett
# 39182      Sheila Kohler
# 39183     Evan H. Rhodes
# 39184     Philip T. Sudo
#
# [39185 rows x 1 columns]

# %% [markdown]
# I only need the unique authors

# %%
popular_authors.drop_duplicates(inplace=True)
popular_authors
# Out:
#              Book-Author
# 0         Bernice Kanner
# 1       CLAIRE BERLINSKI
# 2         Brendan Halpin
# 3      Dorothy J. Gaiter
# 4          Robert Harris
# ...                  ...
# 39174     Susan W. Wells
# 39177        Sally Laird
# 39178      Brian Masters
# 39183     Evan H. Rhodes
# 39184     Philip T. Sudo
#
# [27114 rows x 1 columns]

# %% [markdown]
# # The most popular books with implicit rating

# %%
implicit_ratings = book_ratings_df.drop(book_ratings_df[book_ratings_df['Book-Rating'] > 0].index)

# %%
a = implicit_ratings['ISBN'].value_counts().to_frame().reset_index

# %%
implicit_ratings_nr = implicit_ratings.groupby('ISBN', as_index=False).agg(nr_ratings=('ISBN', 'count'))
implicit_ratings_nr.sort_values('nr_ratings', ascending=False, inplace=True)

# %%
implicit_ratings_over_150 = implicit_ratings_nr.drop(implicit_ratings_nr[implicit_ratings_nr['nr_ratings'] < 150].index)

# %%
popular_books_implicit = pd.merge(implicit_ratings_over_150, books_df, on='ISBN')
popular_books_implicit
# Out:
#            ISBN  nr_ratings                                       Book-Title  \
# 0    0971880107        1921                                      Wild Animus
# 1    0316666343         588                        The Lovely Bones: A Novel
# 2    0060928336         412  Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 3    0385504209         396                                The Da Vinci Code
# 4    044023722X         366                                  A Painted House
# ..          ...         ...                                              ...
# 109  034540288X         152                                   The Lost World
# 110  0446607657         152                              When the Wind Blows
# 111  0425175405         151                                     Black Notice
# 112  0380789035         151                                    American Gods
# 113  080411868X         151                 Welcome to the World, Baby Girl!
#
# ...

# %% [markdown]
# # Google Books API for books short description

# %%
import requests

# Your API key
api_key = 'AIzaSyBKTcw0Du6f4-66SIo3LiiTNfspfLO-_As'

#GET https://www.googleapis.com/books/v1/volumes?q=flowers+inauthor:keyes&key=yourAPIKey

# Function to get the short description of a book
def get_book_description(isbn):#(title, author):
    # Query the Google Books API
    url = 'https://www.googleapis.com/books/v1/volumes'
    #params = {'q': f'intitle:{title}+inauthor:{author}', 'key': api_key}
    params = {'q': f'isbn:{isbn}', 'key': api_key}
    response = requests.get(url, params=params)
    data = response.json()

    # Extract the short description
    try:
      if 'items' in data:
        return data['items'][0]['volumeInfo']['description']

      else:
          return None
    except:
      return None

# %% [markdown]
# For the most popular 1000 books we will add a short description

# %%
popular_books_1000 = popular_books.head(1000)

# %%
# Create a new column for the short descriptions
popular_books_1000['Description'] = popular_books_1000.apply(lambda row: get_book_description(row['ISBN']), axis=1)
display(popular_books_1000)
# Out:
# <ipython-input-223-28db718247db>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popular_books_1000['Description'] = popular_books_1000.apply(lambda row: get_book_description(row['ISBN']), axis=1)
#            ISBN  Book-Rating  \
# 0    0812929950         10.0
# 1    0812967097         10.0
# 2    0812966872         10.0
# 3    0812966864         10.0
# 4    0812966538         10.0
# ..          ...          ...
# 995  0765307316         10.0
# 996  076530726X         10.0
# 997  0765307235         10.0
# 998  0765302268         10.0
# 999  0765301938         10.0
#
#                                             Book-Title        Book-Author  \
# 0         100 Best TV Commercials: And Why They Worked     Bernice Kanner
# ...

# %% [markdown]
# # Wikipedia API for the popular authors

# %%
# !pip3 install wikipedia-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# function to get short description from Wikipedia API
def get_description(author):
    url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{author}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if "extract" in data:
            return data['extract']
    return ""

# %% [markdown]
# For the most popular 1000 authors I will add a short description

# %%
popular_authors_1000 = popular_authors.head(1000)

# %%
popular_authors_1000['Description'] = popular_authors_1000['Book-Author'].apply(lambda x: get_description(x))
# Out:
# <ipython-input-237-ecf383de4c9f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popular_authors_1000['Description'] = popular_authors_1000['Book-Author'].apply(lambda x: get_description(x))

# %%
popular_authors_1000
# Out:
#             Book-Author                                        Description
# 0        Bernice Kanner
# 1      CLAIRE BERLINSKI
# 2        Brendan Halpin
# 3     Dorothy J. Gaiter  Dorothy J. Gaiter and John Brecher are America...
# 4         Robert Harris                 Robert or Rob Harris may refer to:
# ...                 ...                                                ...
# 1135      Thomas Malory  Sir Thomas Malory was an English writer, the a...
# 1136    Walter Benjamin  Walter Bendix Schönflies Benjamin was a German...
# 1137   Jerome Goldstein  Jerome (Jerry) Arthur Goldstein is an American...
# 1138    Chuck Palahniuk  Charles Michael "Chuck" Palahniuk is an Americ...
# 1139    Gennadii Spirin
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Save the client's requested data in CSV file

# %%
popular_authors_1000.to_csv('The most popular 1000 authors.csv', index = True)
popular_books_1000.to_csv('The most popular 1000 books.csv', index = True)
